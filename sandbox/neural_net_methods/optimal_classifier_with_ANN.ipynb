# %% [markdown]
# this script uses neural nets in the following places
# * for part of speech classification in lemmatization
# * word2Vec semantic embeddings
#
# Ideally we can do several things here:
# * use existing word embeddings to classify summary text
# * use more sentiment analysis to classify review text
# * have a classifier that enforces True iff review text is true and summary text is true (true = awesome)
# * assign sentiments to nouns, identify relevant/irrelevant nouns, and classify based on their sentiments
#
# sentiment analysis alg idea:
# find adj-noun pairs
# train classifier on training set based on noun semantics. Identify relevant nouns by a threshold over the SVM coefficients
# train classifer on training set based on verb semantics.
# predict outcome based on verbs attached to relevant nouns.

# %%
# %load_ext autoreload
# %autoreload 2
import time
start_time = time.time()

import json

import numpy as np

import sys
sys.path.append("../../libraries/")
from selector import split_data
from semanticClassifiers import docTopTransformer2,bigramsPhraser

# %%
# Read in testing data for 80/20 split
# we won't use val_dat at all
json_dat, val_dat = split_data('../../data/Sports_and_Outdoors_Reviews_training.json', 80)
json_dat = json_dat[0:141792]
del val_dat

# %%
# create lists with one review per elem
summary = []
review = []
rating = []
prod_id = []
for i in range(0,len(json_dat)):
    if json_dat[i].get('summary'): #not all reviews have text
        rating.append(json_dat[i].get('overall'))
        summary.append(json_dat[i].get('summary'))
        prod_id.append(json_dat[i].get('asin'))
        
del json_dat

# %%
# the get_wordnet_pos() function relies on a neural method, 
# and preprocess_data_lemmatize therefore does too. Implemented
# here for some benchmarking only

import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from spellchecker import SpellChecker


def get_wordnet_pos(tag):
    """Map POS tag to first character lemmatize() accepts"""
    tag = tag[0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)


def preprocess_data_lemmatize(doc_set):
    """
    Input  : docuemnt list
    Purpose: preprocess text (tokenize, removing stopwords, and stemming)
    Output : preprocessed text
    """
    # initialize regex tokenizer
    tokenizer = RegexpTokenizer(r'\w+')
    # create spell checker
    sc = SpellChecker()
    # create English stop words list
    en_stop = set(stopwords.words('english'))
    # create spell checker
    sp = SpellChecker()
    # Create lemmatizer class
    wordnet_lemmatizer = WordNetLemmatizer()    
    # list for tokenized documents in loop
    texts = []
    # loop through document list
    for i in doc_set:
        # clean and tokenize document string
        raw = i.lower()
        tokens = tokenizer.tokenize(raw)
        # autocorrect spelling
        tokens = [sp.correction(this_tok) for this_tok in tokens]
        # get part of speech tag
        this_pos = [tag[1] for tag in nltk.pos_tag(tokens)]
        # remove stop words from tokens, also return associatd tags
        stopped_tokens = [(this_tok, this_pos[i]) for i,this_tok in enumerate(tokens)
                          if not this_tok in en_stop]        
        # lemmatize tokens
        lemmatized_tokens = [wordnet_lemmatizer.lemmatize(this_tok[0], pos=get_wordnet_pos(this_tok[1]))
                             for this_tok in stopped_tokens]
        # add tokens to list
        texts.append([(this_tok, this_pos[i]) for i,this_tok in enumerate(lemmatized_tokens)])
    return texts

# %%
import time
t0 = time.time()
awesome = np.array(rating) >= 4.5
lem_summary_text = preprocess_data_lemmatize(summary[0:40000])
t1 = time.time()
#del summary
#del review

print(t1-t0)
lem_summary_text
# Out:
# 317.3825571537018
# [[('three', 'CD'), ('star', 'NNS')],
#  [('much', 'RB'), ('good', 'JJR'), ('plastic', 'IN'), ('cap', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('roll', 'NN'), ('dice', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('crook', 'VBN'), ('thread', 'NNS')],
#  [('arrive', 'VBN'),
#   ('time', 'IN'),
#   ('product', 'NN'),
#   ('exactly', 'NN'),
#   ('described', 'VBD')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('let', 'NNS'), ('go', 'VBP'), ('mets', 'NNS')],
#  [('go', 'VB'), ('tiger', 'NNS'), ('great', 'JJ'), ('quality', 'NN')],
#  [('nice', 'RB'),
#   ('sport', 'JJ'),
#   ('lanyard', 'NNS'),
#   ('support', 'NN'),
#   ('team', 'TO'),
#   ('work', 'VB'),
#   ('great', 'PRP$'),
#   ('nice', 'NN'),
#   ('buy', 'VBZ'),
#   ('good', 'JJ'),
#   ('price', 'JJ')],
#  [('nice', 'RB')],
#  [('buy', 'NN'), ('bro', 'VBD'), ('law', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('three', 'CD'), ('star', 'NNS')],
#  [('excellent', 'NN'), ('quality', 'CC'), ('lanyard', 'NN')],
#  [('good', 'JJ'), ('quality', 'NN')],
#  [('make', 'VB'), ('sure', 'JJ'), ('know', 'PRP'), ('buy', 'VBP')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('lanyard', 'PRP'), ('nothing', 'VBZ'), ('special', 'DT')],
#  [('key', 'NN'), ('month', 'VBP')],
#  [('also', 'PRP'),
#   ('wash', 'RB'),
#   ('well', 'VBZ'),
#   ('sink', 'RB'),
#   ('little', 'IN'),
#   ('soap', 'DT'),
#   ('water', 'NN'),
#   ('get', 'IN'),
#   ('dirty', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'), ('quality', 'NN'), ('lanyard', 'NN')],
#  [('expect', 'RB')],
#  [('ideal', 'RB'), ('good', 'VB'), ('option', 'JJR')],
#  [('love', 'PRP')],
#  [('easy', 'JJ'), ('gift', 'NN'), ('giant', 'IN'), ('fan', 'NNS')],
#  [],
#  [('good', 'JJ'), ('quality', 'NN'), ('lanyard', 'NN')],
#  [('work', 'PRP')],
#  [('go', 'VB'), ('seabird', 'NNS')],
#  [('good', 'JJ')],
#  [('pre-ski', 'NN')],
#  [('nice', 'JJ')],
#  [('good', 'JJ'), ('quality', 'NN'), ('product', 'NN')],
#  [('kinda', 'NN'), ('big', 'JJ')],
#  [('nice', 'RB'), ('lanyard', 'JJ')],
#  [('tt', 'VBD'), ('expect', 'JJ'), ('plastic', 'VBG')],
#  [('nice', 'JJ'), ('lanyard', 'NN')],
#  [('great', 'JJ')],
#  [('lanyard', 'PRP')],
#  [('must', 'MD'), ('sf', 'VB'), ('giant', 'IN'), ('fan', 'JJ')],
#  [('red', 'JJ'), ('sox', 'NN'), ('lanyard', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('uncle', 'NN'),
#   ('mike', 'NN'),
#   ('rectangular', 'VBD'),
#   ('pad', 'NN'),
#   ('pistol', 'VBD'),
#   ('pouch', 'NN'),
#   ('medium', 'JJ')],
#  [('pistol', 'DT'), ('pouch', 'NN'), ('well', 'NN'), ('construct', 'VBZ')],
#  [('perfect', 'JJ'),
#   ('size', 'NN'),
#   ('shape', 'NN'),
#   ('padding', 'NN'),
#   ('security', 'CC'),
#   ('slide', 'NN')],
#  [('super', 'JJ'),
#   ('super', 'NN'),
#   ('long', 'RB'),
#   ('shipping', 'JJ'),
#   ('time', 'NN')],
#  [('great', 'JJ'), ('case', 'NN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('perfect', 'NN'), ('price', 'IN')],
#  [('great', 'JJ'), ('product', 'NN')],
#  [('really', 'DT'), ('nice', 'VBZ'), ('bag', 'DT')],
#  [('much', 'RB'), ('good', 'JJ'), ('thing', 'IN')],
#  [('good', 'JJ'), ('anything', 'IN'), ('value', 'NN')],
#  [('uncle', 'NN'),
#   ('mike', 'NN'),
#   ('rectangular', 'VBD'),
#   ('pad', 'NN'),
#   ('pistol', 'VBD'),
#   ('pouch', 'NN'),
#   ('medium', 'JJ')],
#  [('great', 'JJ')],
#  [('smell', 'NNS'), ('funny', 'VBP')],
#  [('wrong', 'JJ'), ('item', 'NN'), ('medium', 'RB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('okay', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('product', 'NN'),
#   ('great', 'JJ'),
#   ('price', 'NN'),
#   ('issue', 'DT')],
#  [('propane', 'NN'), ('adapter', 'NN')],
#  [('tactical', 'JJ'),
#   ('crusader', 'NN'),
#   ('pro', 'JJ'),
#   ('a1', 'NN'),
#   ('metal', 'NN'),
#   ('airport', 'NN'),
#   ('propane', 'NN'),
#   ('adapter', 'NN')],
#  [('advertised', 'IN'), ('complaint', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('one', 'CD'), ('star', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('three', 'CD'), ('star', 'NNS')],
#  [('would', 'NN'), ('recommend', 'MD'), ('product', 'VB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'), ('buy', 'NN')],
#  [('work', 'PRP'), ('ok', 'VBZ'), ('build', 'JJ'), ('well', 'CC')],
#  [('great', 'JJ')],
#  [('great', 'JJ'),
#   ('product', 'NN'),
#   ('expect', 'NN'),
#   ('see', 'VBD'),
#   ('machining', 'VBG'),
#   ('defect', 'TO')],
#  [('cool', 'DT'), ('adapter', 'VBZ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('definitely', 'RB'),
#   ('one', 'CD'),
#   ('good', 'IN'),
#   ('propane', 'DT'),
#   ('adaptor', 'JJR'),
#   ('try', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('work', 'DT'),
#   ('good', 'VBZ'),
#   ('could', 'RB'),
#   ('say', 'JJ'),
#   ('love', 'NN')],
#  [('work', 'NNS'), ('fine', 'RB')],
#  [('great', 'PRP$'),
#   ('adapter', 'DT'),
#   ('u', 'JJ'),
#   ('use', 'NN'),
#   ('lot', 'CC')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('shut', 'RB'), ('take', 'VBN'), ('money', 'RP')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('work', 'NNS'), ('perfectly', 'RB')],
#  [('perfect', 'NN')],
#  [('need', 'RB')],
#  [('sweet', 'NN')],
#  [('good', 'RB'), ('adapter', 'JJ')],
#  [('work', 'NNS'), ('great', 'JJ'), ('durable', 'CC'), ('build', 'JJ')],
#  [('work', 'NNS'), ('great', 'JJ'), ('save', 'CC'), ('money', 'VBZ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('three', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('fit', 'NN')],
#  [('keep', 'VBZ'),
#   ('hair', 'VB'),
#   ('dry', 'VB'),
#   ('despite', 'NN'),
#   ('claim', 'JJ'),
#   ('contrary', 'IN')],
#  [('good', 'JJ'), ('quality', 'NN')],
#  [('good', 'JJ'), ('stuff', 'NN')],
#  [('high', 'JJ'),
#   ('quality', 'NN'),
#   ('silicone', 'NN'),
#   ('cap', 'NN'),
#   ('much', 'RB'),
#   ('thick', 'JJR'),
#   ('flimsy', 'IN')],
#  [('small', 'JJ')],
#  [('absolutely', 'RB'),
#   ('perfect', 'NN'),
#   ('thick', 'IN'),
#   ('long', 'DT'),
#   ('hair', 'NN')],
#  [('good', 'JJ'), ('fit', 'NN')],
#  [('great', 'JJ'),
#   ('swim', 'JJ'),
#   ('cap', 'NN'),
#   ('thick', 'IN'),
#   ('hair', 'JJ')],
#  [('durable', 'JJ')],
#  [('excellent', 'JJ'), ('swim', 'NN'), ('cap', 'NN')],
#  [('daughter', 'NN'), ('like', 'VBZ')],
#  [('good', 'PRP'),
#   ('product', 'VBZ'),
#   ('also', 'DT'),
#   ('come', 'JJ'),
#   ('nose', 'NN')],
#  [('great', 'JJ'), ('fit', 'NN'), ('feel', 'CC')],
#  [('love', 'VB')],
#  [('one', 'CD'), ('major', 'JJ'), ('flaw', 'NN')],
#  [('gun', 'NN'), ('stock', 'NN')],
#  [('fit', 'VBZ')],
#  [('hogue', 'NN'), ('quality', 'NN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('three', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('sweet', 'NN')],
#  [('nice', 'JJ'), ('large', 'JJ'), ('burner', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('nice', 'JJ'), ('stove', 'NN'), ('big', 'IN'), ('pot', 'JJR')],
#  [('great', 'JJ'), ('price', 'NN'), ('work', 'CC'), ('flawlessly', 'VBZ')],
#  [('buy', 'WRB'), ('figure', 'NN')],
#  [('work', 'VBN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('love', 'VB')],
#  [('great', 'JJ'),
#   ('stove', 'NN'),
#   ('turn', 'IN'),
#   ('real', 'NN'),
#   ('low', 'MD')],
#  [('need', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('perfect', 'NN'),
#   ('back', 'IN'),
#   ('packing', 'JJ'),
#   ('cook', 'NN'),
#   ('power', 'CC')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('lightweight', 'JJ'),
#   ('compact', 'NN'),
#   ('come', 'VBZ'),
#   ('small', 'IN'),
#   ('case', 'JJ')],
#  [('great', 'JJ'), ('product', 'NN'), ('anything', 'IN'), ('improve', 'EX')],
#  [('cook', 'VBN'),
#   ('sausage', 'NN'),
#   ('egg', 'CC'),
#   ('full', 'NNS'),
#   ('size', 'IN'),
#   ('frying', 'DT'),
#   ('pan', 'JJ')],
#  [('happy', 'NN'), ('purchase', 'VBP')],
#  [('nice', 'JJ'),
#   ('nice', 'JJ'),
#   ('nice', 'JJ'),
#   ('great', 'JJ'),
#   ('product', 'NN')],
#  [('seem', 'VBZ'), ('good', 'JJ')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('awesome', 'JJ'),
#   ('light', 'NN'),
#   ('show', 'NN'),
#   ('see', 'IN'),
#   ('bright', 'DT'),
#   ('color', 'TO')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('inexpensive', 'JJ'), ('weather', 'CC'), ('resistant', 'RB')],
#  [('son', 'PRP$'), ('love', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('brite', 'NN'), ('light', 'NN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('need', 'NN'),
#   ('well', 'RBR'),
#   ('adhesive', 'JJ'),
#   ('look', 'CC'),
#   ('awesome', 'VBZ'),
#   ('board', 'VBP')],
#  [('even', 'RB'),
#   ('player', 'DT'),
#   ('hater', 'NN'),
#   ('kid', 'NN'),
#   ('street', 'NNS'),
#   ('love', 'RP')],
#  [('nice', 'JJ'),
#   ('light', 'NNS'),
#   ('hard', 'CC'),
#   ('fit', 'JJ'),
#   ('penny', 'TO')],
#  [('visible', 'JJ'), ('night', 'IN')],
#  [('warm', 'NN'), ('comfortable', 'CC')],
#  [('awesome', 'NN'), ('bike', 'IN'), ('cold', 'VBG')],
#  [('great', 'JJ'), ('pair', 'NN'), ('glove', 'IN')],
#  [('great', 'JJ'), ('glove', 'NNS')],
#  [('good', 'JJ'), ('pair', 'NN'), ('glove', 'IN')],
#  [('great', 'JJ'),
#   ('chilly', 'IN'),
#   ('weather', 'RB'),
#   ('cold', 'VBZ'),
#   ('weather', 'RB'),
#   ('rid', 'JJ')],
#  [('okay', 'PRP'), ('still', 'VBZ'), ('use', 'JJ')],
#  [('nice', 'JJ'),
#   ('lightweight', 'VBD'),
#   ('glove', 'NN'),
#   ('moderate', 'IN'),
#   ('weather', 'JJ')],
#  [('love', 'VB')],
#  [('keep', 'VB'), ('hand', 'PRP$'), ('warm', 'NNS')],
#  [('great', 'JJ'), ('glove', 'NNS')],
#  [('great', 'JJ'), ('glove', 'NNS')],
#  [('good', 'JJ'), ('simple', 'CC')],
#  [('enough', 'RB'), ('pad', 'RB')],
#  [('buy', 'VBP')],
#  [('good', 'JJ'), ('glove', 'NNS')],
#  [('great', 'JJ'), ('30', 'RP')],
#  [('driver', 'NNS'),
#   ('see', 'MD'),
#   ('hand', 'VB'),
#   ('gesture', 'PRP$'),
#   ('night', 'NN')],
#  [('work', 'PRP'), ('ok', 'VBP'), ('glove', 'JJ')],
#  [('winter', 'NN'), ('glove', 'NNS')],
#  [('pi', 'NN'), ('thermal', 'JJ'), ('glove', 'NNS')],
#  [('fit', 'NN'), ('like', 'IN'), ('glove', 'DT')],
#  [('good', 'JJ'), ('overall', 'NN')],
#  [('great', 'JJ'), ('glove', 'IN'), ('glove', 'DT')],
#  [('thermal', 'JJ'), ('glove', 'RB')],
#  [('want', 'VBN'), ('warmer', 'NN')],
#  [('stylish', 'JJ'), ('good', 'JJ'), ('value', 'NN')],
#  [('mild', 'NN'), ('rid', 'VBG')],
#  [('cold', 'JJ'), ('weather', 'NN'), ('glove', 'NN')],
#  [('really', 'DT'), ('nice', 'RB'), ('pair', 'JJ'), ('glove', 'NN')],
#  [('good', 'JJ'), ('balance', 'NN'), ('bulky', 'RB'), ('thin', 'RB')],
#  [('keep', 'VBZ'), ('wind', 'DT'), ('away', 'NN')],
#  [('great', 'JJ'), ('glove', 'NNS')],
#  [('light', 'JJR'), ('expect', 'IN'), ('still', 'VBN'), ('warm', 'CC')],
#  [('cool', 'NN'), ('weather', 'NN'), ('problem', 'DT')],
#  [('high', 'JJ'), ('quality', 'NN')],
#  [('good', 'JJ'), ('cooler', 'IN'), ('day', 'NN')],
#  [('nice', 'JJ'),
#   ('feel', 'NN'),
#   ('good', 'CC'),
#   ('wind', 'JJ'),
#   ('protection', 'NN')],
#  [('thermal', 'RB')],
#  [('excellent', 'JJ'), ('layer', 'NN')],
#  [('good', 'RB'),
#   ('chicago', 'JJ'),
#   ('30', 'IN'),
#   ('degree', 'RB'),
#   ('weather', 'CD')],
#  [('good', 'JJ'), ('glove', 'NNS')],
#  [('outstanding', 'JJ')],
#  [('great', 'JJ'), ('base', 'NN'), ('layer', 'NN')],
#  [('good', 'JJ'), ('glove', 'NNS')],
#  [('good', 'JJ'), ('35', 'IN'), ('degree', 'CD')],
#  [('best', 'RB'),
#   ('value', 'DT'),
#   ('even', 'JJS'),
#   ('though', 'NN'),
#   ('expensive', 'RB')],
#  [('pearl', 'NN'),
#   ('sum', 'NN'),
#   ('scream', 'VBG'),
#   ('yellow', 'JJ'),
#   ('thermal', 'JJ'),
#   ('glove', 'NNS')],
#  [('good', 'JJ'), ('product', 'NN')],
#  [('great', 'JJ'), ('cold', 'JJ'), ('weather', 'NN'), ('glove', 'NNS')],
#  [('warm', 'RB'), ('enough', 'JJ'), ('bike', 'RB')],
#  [('good', 'JJ'),
#   ('40', 'RB'),
#   ('degree', 'TO'),
#   ('c', 'CD'),
#   ('work', 'NNS'),
#   ('phone', 'VBP')],
#  [('want', 'WP')],
#  [('warm', 'JJ'), ('glove', 'NN')],
#  [('excellent', 'NN'), ('cool', 'IN'), ('weather', 'NN')],
#  [('great', 'JJ'), ('fit', 'JJ'), ('great', 'JJ'), ('glove', 'NNS')],
#  [('great', 'JJ'), ('glove', 'NNS')],
#  [('good', 'JJ'),
#   ('light', 'NN'),
#   ('pair', 'NN'),
#   ('glove', 'IN'),
#   ('cycling', 'NNS')],
#  [('disappoint', 'VBN'),
#   ('hop', 'VBD'),
#   ('good', 'VBG'),
#   ('insulation', 'IN')],
#  [('surprisingly', 'RB'), ('warm', 'JJ'), ('thin', 'IN'), ('glove', 'JJ')],
#  [('lightweight', 'JJ'), ('cycling', 'NN'), ('glove', 'NNS')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('favorite', 'PRP$'), ('glove', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('perfect', 'NN')],
#  [('perfect', 'NN'), ('mild', 'IN'), ('weather', 'NN')],
#  [('really', 'RB'), ('like', 'RB')],
#  [('get', 'PRP'), ('pay', 'VBP')],
#  [('worth', 'IN'), ('money', 'DT')],
#  [('pile', 'NN'), ('crap', 'IN')],
#  [('perfect', 'JJ'), ('buy', 'NN')],
#  [('awesome', 'NN'), ('wait', 'MD'), ('use', 'VB'), ('feature', 'NN')],
#  [('spot', 'NNS'), ('watch', 'VBP')],
#  [('might', 'MD'), ('well', 'RB'), ('chinese', 'RB')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('gerber', 'VB'), ('applegath', 'NN'), ('covert', 'JJ'), ('knife', 'NN')],
#  [('nice', 'DT'), ('pocket', 'VBZ'), ('knife', 'DT')],
#  [('dig', 'NN')],
#  [('ok', 'JJ'), ('knife', 'NN'), ('question', 'CC'), ('remain', 'NNS')],
#  [('sexy', 'NN'), ('bad', 'RB'), ('bad', 'JJ')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'),
#   ('blade', 'NN'),
#   ('hold', 'VBZ'),
#   ('edge', 'RB'),
#   ('well', 'RB'),
#   ('good', 'CC'),
#   ('ergonomics', 'JJ')],
#  [('one', 'CD'), ('star', 'NN')],
#  [('folder', 'DT'),
#   ('behave', 'NN'),
#   ('like', 'WDT'),
#   ('fixed', 'VBZ'),
#   ('blade', 'IN')],
#  [('high', 'DT'), ('quality', 'JJ'), ('versatile', 'NN'), ('knife', 'IN')],
#  [('sharpness', 'NN')],
#  [('applegath', 'NN')],
#  [('great', 'JJ'), ('knife', 'NN')],
#  [('get', 'MD'), ('much', 'VB'), ('good', 'VB'), ('knife', 'RB')],
#  [('great', 'JJ'), ('knife', 'NN')],
#  [('great', 'DT'), ('knife', 'JJ')],
#  [('really', 'RB'),
#   ('like', 'RB'),
#   ('knife', 'IN'),
#   ('gerber', 'DT'),
#   ('warranty', 'NN'),
#   ('service', 'CC'),
#   ('quick', 'VB')],
#  [('faulty', 'NN'), ('liner', 'NN'), ('lock', 'NN')],
#  [('5', 'CD'), ('star', 'NNS')],
#  [('small', 'JJ'), ('light', 'JJ'), ('duty', 'NN'), ('knife', 'NN')],
#  [('good', 'JJ'), ('reel', 'NN'), ('smooth', 'NNS'), ('comfortable', 'CC')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('think', 'NN'), ('good', 'VBP'), ('reel', 'EX'), ('money', 'VBP')],
#  [('look', 'VBZ'),
#   ('handle', 'NNS'),
#   ('like', 'IN'),
#   ('much', 'DT'),
#   ('expensive', 'RB'),
#   ('reel', 'RBR')],
#  [('excellent', 'NN'), ('money', 'IN')],
#  [('thumb', 'NNS')],
#  [('great', 'JJ'), ('little', 'JJ'), ('lever', 'NN')],
#  [('mission', 'NN'), ('accomplish', 'VBD')],
#  [('take', 'VBZ'), ('genius', 'NNS')],
#  [('nice', 'JJ'), ('brake', 'NN'), ('lever', 'NN')],
#  [('good', 'JJ'), ('kind', 'IN'), ('thing', 'DT')],
#  [('work', 'NNS')],
#  [('small', 'JJ'), ('strip', 'CC')],
#  [('really', 'NN'), ('love', 'RB')],
#  [('delivery', 'NN'), ('great', 'JJ')],
#  [('nice', 'RB'), ('lot', 'JJ'), ('detail', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('highly', 'RB'), ('recommended', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('product', 'NN'),
#   ('clean', 'IN'),
#   ('well', 'JJ'),
#   ('teach', 'RP')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('tempt', 'NN')],
#  [('mat', 'PRP')],
#  [('great', 'JJ'), ('idea', 'NN'), ('gun', 'IN'), ('owner', 'NN')],
#  [('three', 'CD'), ('star', 'NNS')],
#  [('accurate', 'NN'), ('well', 'RB'), ('make', 'VBD')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('keep', 'VBG'),
#   ('table', 'PRP$'),
#   ('top', 'NN'),
#   ('clean', 'JJ'),
#   ('firearm', 'NN'),
#   ('cushion', 'CC')],
#  [('tempt', 'JJ'),
#   ('ruger', 'NN'),
#   ('lc', 'NN'),
#   ('pistol', 'NN'),
#   ('gun', 'NN'),
#   ('clean', 'VBG'),
#   ('mat', 'JJ'),
#   ('black', 'JJ')],
#  [('great', 'JJ'),
#   ('mat', 'NN'),
#   ('make', 'VBZ'),
#   ('nice', 'PRP'),
#   ('see', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('quality', 'NN'), ('price', 'CC')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('love', 'VB'), ('scarf', 'PRP$')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('nice', 'RB'), ('quality', 'JJ')],
#  [('well', 'RB'), ('make', 'VBN'), ('nice', 'JJ'), ('length', 'NN')],
#  [('steelers', 'NNS'), ('scarf', 'VBP')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('look', 'VBG'),
#   ('probably', 'CC'),
#   ('functional', 'RB'),
#   ('scarf', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('first', 'JJ'), ('year', 'NN'), ('bengal', 'NN'), ('fan', 'NN')],
#  [('baltimore', 'NN'), ('raven', 'NNS'), ('scarf', 'VBP')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('love', 'VB')],
#  [('happy', 'JJ')],
#  [('great', 'JJ'), ('quality', 'NN'), ('material', 'NN')],
#  [('buy', 'NN'), ('gift', 'VBD'), ('sister', 'DT'), ('law', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('make', 'VBN'), ('great', 'JJ'), ('love', 'JJ'), ('describe', 'VBP')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('sun', 'NN'),
#   ('shade', 'VBG'),
#   ('without', 'IN'),
#   ('overheat', 'VBG'),
#   ('rest', 'DT')],
#  [('woman', 'NN'), ('love', 'VBP'), ('hat', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('nice', 'JJ'), ('hat', 'NN')],
#  [('new', 'JJ'), ('favorite', 'NN'), ('hat', 'NN')],
#  [('nice', 'JJ')],
#  [('like', 'VB'), ('tiger', 'RB'), ('wood', 'IN')],
#  [('great', 'JJ'), ('hat', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('fun', 'PRP')],
#  [('like', 'IN'), ('gallagher', 'NN')],
#  [('love', 'NN'), ('knife', 'VBP')],
#  [('nice', 'DT'),
#   ('novelty', 'JJ'),
#   ('item', 'NN'),
#   ('earn', 'NN'),
#   ('3', 'VBZ'),
#   ('1', 'CD'),
#   ('2', 'CD'),
#   ('star', 'CD'),
#   ('easily', 'NNS')],
#  [('crt', 'NN'), ('glide', 'NN'), ('lock', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('three', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('many', 'JJ'), ('compliment', 'NNS')],
#  [('tn', 'NNS'), ('pride', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('patch', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('patch', 'NN')],
#  [('high', 'JJ'), ('quality', 'NN'), ('product', 'NN')],
#  [('nice', 'JJ'),
#   ('quality', 'NN'),
#   ('velcro', 'NN'),
#   ('back', 'VBD'),
#   ('patch', 'NN')],
#  [('quality', 'NN'),
#   ('good', 'VBZ'),
#   ('seem', 'JJ'),
#   ('hold', 'CC'),
#   ('well', 'PRP')],
#  [('great', 'JJ'), ('flag', 'NN'), ('patch', 'NN')],
#  [('nice', 'JJ'), ('stuff', 'NN')],
#  [('please', 'JJ'),
#   ('high', 'NNS'),
#   ('quality', 'VBN'),
#   ('product', 'IN'),
#   ('prompt', 'DT'),
#   ('service', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('patch', 'NN')],
#  [('great', 'JJ'), ('patch', 'NN'), ('outstanding', 'JJ'), ('company', 'NN')],
#  [('volunteer', 'PRP'), ('america', 'VBP')],
#  [('retire', 'VBN'), ('278th', 'IN'), ('tn', 'DT'), ('know', 'CD')],
#  [('love', 'VBD')],
#  [('like', 'NNS'), ('look', 'IN'), ('black', 'WRB'), ('white', 'PRP')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('patch', 'NN')],
#  [('thumb', 'NNS')],
#  [('excellent', 'NN')],
#  [('clean', 'JJ'), ('classy', 'CC')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('fast', 'RB'),
#   ('ship', 'VBG'),
#   ('item', 'NN'),
#   ('describe', 'IN'),
#   ('last', 'VBN'),
#   ('2', 'VBD')],
#  [('great', 'JJ'), ('product', 'NN')],
#  [('brother', 'IN')],
#  [('steelers', 'NNS')],
#  [('best', 'JJS'), ('gift', 'NN'), ('hubby', 'IN')],
#  [('great', 'JJ'), ('deal', 'NN')],
#  [('show', 'VBG'),
#   ('true', 'JJ'),
#   ('steep', 'JJ'),
#   ('pride', 'NN'),
#   ('deal', 'IN')],
#  [('need', 'NNS'), ('work', 'NN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('expect', 'RB'), ('size', 'WP'), ('standard', 'NN'), ('rail', 'VBD')],
#  [('work', 'VBN'), ('well', 'RB'), ('great', 'CC'), ('price', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('high', 'JJ'), ('quality', 'NN'), ('good', 'JJ'), ('price', 'NN')],
#  [('work', 'NNS')],
#  [('great', 'JJ'), ('mount', 'NN'), ('adapter', 'NN')],
#  [('good', 'RB'), ('product', 'JJ')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('tomahawk', 'NN')],
#  [('great', 'JJ'), ('value', 'NN'), ('buck', 'IN')],
#  [('kershaw', 'RB'), ('good', 'JJ'), ('tac', 'NN'), ('tomahawk', 'NN')],
#  [('feel', 'NNS'),
#   ('like', 'IN'),
#   ('good', 'DT'),
#   ('solid', 'JJ'),
#   ('hawk', 'JJ')],
#  [('great', 'PRP$')],
#  [('awesome', 'NN')],
#  [('buy', 'WRB')],
#  [('buy', 'VB')],
#  [('come', 'VBD'),
#   ('dull', 'NN'),
#   ('sheath', 'CC'),
#   ('tight', 'NN'),
#   ('snap', 'TO'),
#   ('shut', 'VB')],
#  [('hammer', 'NN'),
#   ('like', 'IN'),
#   ('back', 'VBN'),
#   ('would', 'MD'),
#   ('much', 'VB'),
#   ('useful', 'RB')],
#  [('come', 'VBZ'), ('sharp', 'RB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('totally', 'RB'), ('worth', 'JJ')],
#  [('reason', 'DT'), ('call', 'NN'), ('great', 'TO'), ('buy', 'RB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('tool', 'NN')],
#  [('great', 'JJ')],
#  [('decent', 'JJ'),
#   ('product', 'NN'),
#   ('terrible', 'JJ'),
#   ('packaging', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('exactly', 'RB'), ('need', 'WP')],
#  [('great', 'JJ'), ('hawk', 'NN')],
#  [('wow', 'NNS'), ('glad', 'RB'), ('get', 'JJ')],
#  [('2', 'CD'), ('good', 'JJ'), ('2', 'CD'), ('b', 'NN'), ('true', 'JJ')],
#  [('best', 'DT'), ('price', 'JJS'), ('imho', 'IN')],
#  [('awesome', 'NN')],
#  [('good', 'JJ'), ('kershaw', 'NN'), ('hawk', 'NN'), ('money', 'IN')],
#  [('siege', 'NN'), ('right', 'VBZ')],
#  [('like', 'NNS'), ('everything', 'IN'), ('blade', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('awesome', 'JJ'),
#   ('tomahawk', 'NN'),
#   ('well', 'RBR'),
#   ('hop', 'IN'),
#   ('extremely', 'JJ'),
#   ('versatile', 'NN')],
#  [('exactly', 'RB'), ('advertised', 'IN')],
#  [('great', 'JJ'), ('hawk', 'NN'), ('money', 'IN')],
#  [('excellent', 'JJ'), ('deal', 'NN')],
#  [('best', 'JJS'), ('steel', 'NN'), ('money', 'IN'), ('elma', 'PRP$')],
#  [('another', 'DT'), ('great', 'JJ'), ('product', 'NN'), ('kershaw', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('cool', 'DT'), ('axe', 'VBZ'), ('careful', 'DT')],
#  [('great', 'JJ'), ('breaching', 'NN'), ('tool', 'NN')],
#  [('nice', 'PRP'), ('snug', 'VBZ'), ('fit', 'DT')],
#  [('two', 'CD'), ('star', 'NNS')],
#  [('simple', 'NN'),
#   ('reliable', 'JJ'),
#   ('holder', 'NN'),
#   ('gps', 'IN'),
#   ('vhf', 'NN'),
#   ('cold', 'NN')],
#  [('friend', 'PRP$'), ('jealous', 'NNS')],
#  [('order', 'NN'), ('2', 'DT')],
#  [('well', 'RB'), ('worth', 'IN'), ('money', 'DT')],
#  [('great', 'JJ'),
#   ('product', 'NN'),
#   ('ridiculous', 'JJ'),
#   ('packaging', 'NN')],
#  [('nah', 'NN')],
#  [('effective', 'JJ'),
#   ('little', 'CC'),
#   ('bit', 'DT'),
#   ('small', 'JJ'),
#   ('want', 'NN'),
#   ('2', 'JJR'),
#   ('people', 'IN'),
#   ('share', 'NN')],
#  [('keep', 'NNS'),
#   ('dry', 'PRP'),
#   ('windy', 'VBP'),
#   ('rainy', 'IN'),
#   ('chicago', 'DT'),
#   ('day', 'NN')],
#  [('best', 'DT'), ('umbrella', 'JJS'), ('ever', 'NN'), ('use', 'NN')],
#  [('great', 'JJ'), ('umbrella', 'NN')],
#  [('six', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('rainy', 'IN'), ('engagement', 'DT')],
#  [('deceptive', 'JJ'), ('false', 'JJ'), ('advertising', 'NN'), ('size', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('recommend', 'VBN')],
#  [('prepare', 'NN'),
#   ('dry', 'TO'),
#   ('use', 'VB'),
#   ('dustbuster', 'JJ'),
#   ('classic', 'WRB')],
#  [('ok', 'NNS'),
#   ('probably', 'CC'),
#   ('serious', 'RB'),
#   ('quality', 'VBZ'),
#   ('issue', 'JJ')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('dependable', 'JJ'), ('umbrella', 'NN')],
#  [('edit', 'NN'), ('poor', 'JJ'), ('quality', 'NN'), ('umbrella', 'NN')],
#  [('auto', 'PRP'),
#   ('open', 'VBZ'),
#   ('auto', 'NN'),
#   ('close', 'JJ'),
#   ('pretty', 'CC'),
#   ('damn', 'DT'),
#   ('annoy', 'NN')],
#  [('good', 'JJ'), ('coverage', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('48', 'RB'), ('diameter', 'CD'), ('40', 'NN'), ('diameter', 'PRP')],
#  [('must', 'DT')],
#  [('great', 'JJ'), ('umbrella', 'JJ'), ('great', 'JJ'), ('price', 'NN')],
#  [('great', 'DT'), ('light', 'JJ')],
#  [('great', 'JJ'), ('umbrella', 'NN')],
#  [('great', 'JJ'), ('umbrella', 'NN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('like', 'IN'),
#   ('warranty', 'DT'),
#   ('come', 'NN'),
#   ('although', 'WDT'),
#   ('feel', 'VBD'),
#   ('need', 'IN')],
#  [('worth', 'IN'), ('cost', 'DT')],
#  [('bad', 'RB')],
#  [('really', 'DT'), ('good', 'RB'), ('umbrella', 'JJ')],
#  [('umbrella', 'PRP$'),
#   ('choice', 'NN'),
#   ('last', 'IN'),
#   ('9', 'NN'),
#   ('year', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('two', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('well', 'RB'), ('build', 'VBN')],
#  [('best', 'DT'), ('umbrella', 'VBZ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('perfect', 'JJ'), ('size', 'NN'), ('one', 'IN')],
#  [('excellent', 'JJ'),
#   ('great', 'JJ'),
#   ('product', 'NN'),
#   ('great', 'CC'),
#   ('pricing', 'JJ')],
#  [('best', 'JJS'), ('wind', 'NN'), ('defy', 'VBG'), ('umbrella', 'JJ')],
#  [('rain', 'VB'),
#   ('rain', 'WP'),
#   ('see', 'NN'),
#   ('stink', 'JJ'),
#   ('rain', 'VBP')],
#  [('great', 'JJ'), ('umbrella', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('love', 'NN'), ('strong', 'VBP'), ('big', 'PRP')],
#  [('disappointing', 'JJ'),
#   ('stitchworld', 'NN'),
#   ('good', 'JJ'),
#   ('construction', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('investment', 'NN'),
#   ('umbrella', 'IN'),
#   ('stop', 'DT'),
#   ('buying', 'NN'),
#   ('cheap', 'NN'),
#   ('one', 'NN'),
#   ('get', 'JJ'),
#   ('one', 'NNS'),
#   ('good', 'CC'),
#   ('one', 'VB')],
#  [('expensive', 'JJ'),
#   ('umbrella', 'NN'),
#   ('cheap', 'JJ'),
#   ('paint', 'NN'),
#   ('easily', 'RB'),
#   ('chip', 'VBD'),
#   ('handle', 'IN')],
#  [('pricey', 'NN'), ('nice', 'CC'), ('umbrella', 'DT')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('singing', 'NN'), ('dry', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('nice', 'RB'), ('quality', 'JJ'), ('look', 'NN'), ('good', 'CC')],
#  [('small', 'JJ'), ('umbrella', 'NN')],
#  [('sturdy', 'NN')],
#  [('good', 'DT'), ('thing', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('okay', 'NN')],
#  [('beautiful', 'RB'), ('well', 'RB'), ('build', 'VBN'), ('sturdy', 'CC')],
#  [('happy', 'JJ'), ('customer', 'NN')],
#  [('love', 'IN'), ('umbrella', 'NN')],
#  [('umbrella', 'DT'), ('live', 'NN'), ('claim', 'VBZ'), ('video', 'RP')],
#  [('enjoy', 'NN'), ('coverage', 'VBP'), ('umbrella', 'DT'), ('provide', 'NN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('use', 'NN'),
#   ('one', 'VBP'),
#   ('really', 'RB'),
#   ('windy', 'VBD'),
#   ('rainy', 'PRP')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('sound', 'DT')],
#  [('best', 'JJS'), ('umbrella', 'NN'), ('ever', 'RB')],
#  [('good', 'JJ'),
#   ('solid', 'NNS'),
#   ('umbrella', 'RB'),
#   ('big', 'RB'),
#   ('large', 'RB'),
#   ('golf', 'JJ')],
#  [('wife', 'PRP$'), ('love', 'NN'), ('umbrella', 'VBZ')],
#  [('best', 'JJS'), ('umbrella', 'NN'), ('make', 'VBD'), ('break', 'TO')],
#  [('love', 'VB'), ('umbrella', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('make', 'PRP'), ('feel', 'VBZ'), ('british', 'PRP')],
#  [('beautiful', 'DT'), ('umbrella', 'VBZ'), ('rubber', 'DT'), ('tip', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('best', 'JJS'),
#   ('umbrella', 'NN'),
#   ('ever', 'RB'),
#   ('want', 'RB'),
#   ('collapsible', 'VBZ'),
#   ('one', 'VBP')],
#  [('beautiful', 'JJ'),
#   ('classy', 'NN'),
#   ('trustworthy', 'CC'),
#   ('umbrella', 'JJ')],
#  [('probably', 'RB'),
#   ('best', 'DT'),
#   ('quality', 'JJS'),
#   ('umbrella', 'NN'),
#   ('price', 'NN')],
#  [('great', 'JJ')],
#  [('good', 'RB'),
#   ('make', 'JJ'),
#   ('wind', 'VBD'),
#   ('tunnel', 'PRP'),
#   ('nec', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('disappointed', 'JJ')],
#  [('great', 'JJ'),
#   ('umbrella', 'NN'),
#   ('wish', 'RB'),
#   ('auto', 'VB'),
#   ('open', 'PRP')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('umbrella', 'NN')],
#  [('perfect', 'VB'),
#   ('hold', 'PRP'),
#   ('perfectly', 'VBZ'),
#   ('windy', 'RP'),
#   ('weather', 'RB'),
#   ('plus', 'IN')],
#  [('good', 'JJ'), ('quality', 'NN'), ('product', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'RB'), ('tall', 'JJ'), ('people', 'IN')],
#  [('good', 'JJ')],
#  [('outlast', 'MD'),
#   ('3', 'VB'),
#   ('4', 'CD'),
#   ('cheap', 'CD'),
#   ('umbrella', 'JJR'),
#   ('good', 'NNS'),
#   ('value', 'IN')],
#  [('great', 'JJ'), ('umbrella', 'NN')],
#  [('right', 'RB')],
#  [('umbrella', 'DT')],
#  [('look', 'NNS'), ('sharp', 'JJ'), ('work', 'VBZ'), ('perfectly', 'RB')],
#  [('thing', 'NN'), ('beauty', 'IN')],
#  [('large', 'JJ'), ('stem', 'NN'), ('relative', 'JJ'), ('canopy', 'TO')],
#  [('broke', 'NN'), ('3', 'IN'), ('us', 'IN')],
#  [('lemon', 'DT')],
#  [('proper', 'JJ'),
#   ('umbrella', 'NN'),
#   ('one', 'IN'),
#   ('classic', 'CD'),
#   ('look', 'JJ')],
#  [('dustbuster', 'NN'), ('really', 'RB'), ('work', 'VBZ')],
#  [('great', 'JJ'), ('umbrella', 'NN')],
#  [('classy', 'NN')],
#  [('real', 'DT'), ('deal', 'VBZ')],
#  [('umbrella', 'NN')],
#  [('good', 'EX'), ('choice', 'VBP')],
#  [('nec', 'NNS'), ('safe', 'JJ')],
#  [('shell', 'NN'), ('company', 'NN'), ('warranty', 'DT')],
#  [('sturdy', 'RB'), ('well', 'RB'), ('make', 'RB')],
#  [('never', 'RB'), ('good', 'VBD'), ('umbrella', 'DT')],
#  [('great', 'JJ'),
#   ('umbrella', 'JJ'),
#   ('sturdy', 'NN'),
#   ('great', 'IN'),
#   ('look', 'JJ')],
#  [('great', 'JJ'), ('umbrella', 'NN')],
#  [('work', 'NNS')],
#  [('beauty', 'NN'), ('function', 'CC')],
#  [('fragile', 'NN'), ('bad', 'CC'), ('warranty', 'JJ')],
#  [('great', 'JJ')],
#  [('great', 'JJ'), ('quality', 'NN'), ('great', 'JJ'), ('service', 'NN')],
#  [('awesome', 'NN')],
#  [('good', 'JJ'), ('umbrella', 'NN'), ('windy', 'IN'), ('condition', 'JJ')],
#  [('definitely', 'RB'), ('wind', 'NN'), ('test', 'VBD')],
#  [('waste', 'NN'), ('money', 'IN')],
#  [('live', 'VBZ'), ('marketing', 'RP')],
#  [('classy', 'NN'), ('umbrella', 'NN')],
#  [('great', 'JJ'), ('umbrella', 'NN')],
#  [('great', 'JJ'),
#   ('umbrella', 'JJ'),
#   ('even', 'RB'),
#   ('tho', 'VBP'),
#   ('eventually', 'NNS'),
#   ('buy', 'RB'),
#   ('elsewhere', 'VBD')],
#  [('disappointing', 'DT'), ('product', 'JJ')],
#  [('ugly', 'RB'),
#   ('bright', 'JJ'),
#   ('color', 'VBN'),
#   ('logo', 'NN'),
#   ('ruin', 'VBZ'),
#   ('classic', 'DT'),
#   ('look', 'JJ'),
#   ('umbrella', 'VBG')],
#  [('great', 'JJ')],
#  [('great', 'JJ'), ('remote', 'NN')],
#  [('highly', 'RB'), ('recommended', 'JJ')],
#  [('good', 'RB')],
#  [('like', 'NN')],
#  [('easy', 'JJ'), ('forget', 'TO'), ('way', 'VB'), ('way', 'WDT')],
#  [('worth', 'IN'), ('problem', 'PRP')],
#  [('recommendation', 'PRP$'),
#   ('spend', 'NN'),
#   ('buck', 'VBZ'),
#   ('good', 'TO'),
#   ('one', 'RB')],
#  [('must', 'MD')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('best', 'JJS'), ('value', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'), ('quality', 'NN')],
#  [('mean', 'JJ'),
#   ('totally', 'VBP'),
#   ('useless', 'PRP'),
#   ('1', 'VBZ'),
#   ('day', 'RB'),
#   ('use', 'JJ')],
#  [('three', 'CD'), ('star', 'NNS')],
#  [('switch', 'DT'),
#   ('valve', 'IN'),
#   ('totally', 'IN'),
#   ('useless', 'NN'),
#   ('immediate', 'IN'),
#   ('high', 'DT'),
#   ('pressure', 'NN'),
#   ('blow', 'VBZ'),
#   ('magazine', 'RB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ')],
#  [('love', 'VB'), ('water', 'PRP$'), ('bottle', 'NN'), ('carrier', 'NN')],
#  [('awesome', 'WP'), ('gadget', 'DT')],
#  [('100', 'CD'),
#   ('satisfied', 'JJ'),
#   ('water', 'IN'),
#   ('bottle', 'DT'),
#   ('holder', 'NN')],
#  [('perfect', 'DT'), ('water', 'JJ'), ('bottle', 'NN'), ('holder', 'NN')],
#  [('good', 'JJ')],
#  [('okay', 'PRP')],
#  [('perfect', 'DT'),
#   ('solution', 'JJ'),
#   ('annoying', 'NN'),
#   ('problem', 'TO')],
#  [('water', 'NN'), ('bottle', 'NN'), ('holder', 'NN')],
#  [('nice', 'JJ'), ('product', 'NN'), ('work', 'WDT'), ('perfectly', 'VBZ')],
#  [('great', 'DT'), ('useful', 'JJ'), ('gadget', 'JJ')],
#  [('great', 'JJ'), ('way', 'NN'), ('carry', 'TO'), ('water', 'VB')],
#  [('mine', 'NN'),
#   ('never', 'RB'),
#   ('funny', 'VBD'),
#   ('taste', 'DT'),
#   ('sure', 'JJ'),
#   ('reviewer', 'NN')],
#  [('sturdy', 'JJ'), ('best', 'JJS'), ('product', 'NN')],
#  [('good', 'JJ'), ('hardy', 'NN'), ('water', 'NN'), ('storage', 'NN')],
#  [('like', 'VBD'), ('small', 'DT'), ('size', 'JJR')],
#  [('job', 'MD')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'DT'),
#   ('water', 'VBZ'),
#   ('bladder', 'DT'),
#   ('take', 'JJ'),
#   ('trip', 'NN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('disappointed', 'RB'), ('return', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('total', 'JJ'), ('joke', 'NN')],
#  [('big', 'JJ'), ('enough', 'RB'), ('small', 'CC'), ('enough', 'JJ')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('thin', 'JJ'), ('valve', 'CC'), ('work', 'JJ'), ('poorly', 'NNS')],
#  [('work', 'PRP')],
#  [('great', 'JJ'), ('camp', 'IN')],
#  [('job', 'VBZ')],
#  [('product', 'NN'), ('exactly', 'VBZ'), ('advertised', 'RB')],
#  [('great', 'JJ'), ('product', 'NN')],
#  [('okay', 'NN')],
#  [('look', 'NNS'), ('solid', 'JJ')],
#  [('alternative', 'NNS'),
#   ('may', 'MD'),
#   ('work', 'VB'),
#   ('good', 'JJR'),
#   ('method', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('cheaply', 'NN'), ('make', 'VBD')],
#  [('perfect', 'JJ'), ('size', 'NN')],
#  [('2', 'CD'),
#   ('5', 'CD'),
#   ('gallon', 'NN'),
#   ('seem', 'VBZ'),
#   ('like', 'IN'),
#   ('right', 'DT'),
#   ('size', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('company', 'DT'), ('make', 'NN'), ('day', 'VBD')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('work', 'VBN'), ('perfect', 'JJ'), ('tough', 'CC'), ('expect', 'VBD')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('rio', 'NN'),
#   ('fluoflex', 'JJ'),
#   ('saltwater', 'NN'),
#   ('taper', 'VBD'),
#   ('leader', 'NN')],
#  [('great', 'JJ'), ('bonefish', 'JJ'), ('leader', 'NN')],
#  [('small', 'NNS'),
#   ('hand', 'VBP'),
#   ('woman', 'JJ'),
#   ('ring', 'NNS'),
#   ('size', 'NN'),
#   ('5', 'VBP'),
#   ('comfortable', 'VBG')],
#  [('hogue', 'NN'), ('meet', 'NNS'), ('expectation', 'NNS')],
#  [('nice', 'JJ'), ('product', 'NN')],
#  [('love', 'NN'), ('purple', 'NN')],
#  [('great', 'JJ'),
#   ('accessory', 'NN'),
#   ('plain', 'IN'),
#   ('look', 'DT'),
#   ('gun', 'NN')],
#  [('purple', 'JJ'), ('grip', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('p-38', 'JJ'), ('grip', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('nice', 'RB')],
#  [('great', 'JJ'), ('grip', 'NNS')],
#  [('nice', 'JJ'), ('grip', 'NNS')],
#  [('love', 'IN'), ('grip', 'DT')],
#  [('great', 'JJ'), ('grip', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('fast', 'RB'),
#   ('shipping', 'NN'),
#   ('excellent', 'CC'),
#   ('packaging', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('come', 'VBD'),
#   ('super', 'IN'),
#   ('handy', 'JJ'),
#   ('building', 'JJ'),
#   ('first', 'NN'),
#   ('computer', 'PRP$')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('pc', 'NN'), ('screw', 'NN'), ('set', 'NN')],
#  [('exactly', 'RB'), ('need', 'WP'), ('pc', 'NN'), ('maintenance', 'VBD')],
#  [('vg', 'JJ'),
#   ('quality', 'NN'),
#   ('kurt', 'NN'),
#   ('style', 'NN'),
#   ('knife', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('big', 'DT'),
#   ('big', 'JJ'),
#   ('knife', 'JJ'),
#   ('always', 'NN'),
#   ('want', 'PRP'),
#   ('never', 'RB'),
#   ('know', 'VBD'),
#   ('need', 'CC')],
#  [('nice', 'RB'), ('chopper', 'JJ')],
#  [('great', 'JJ'), ('quality', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('flawless', 'NN'), ('sharp', 'CC'), ('box', 'JJ')],
#  [('handle', 'NNS'), ('well', 'RB'), ('sharp', 'RB'), ('pointy', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('three', 'CD'), ('star', 'NNS')],
#  [('love', 'PRP')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('dancer', 'IN'), ('u', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('fun', 'NN')],
#  [('instruction', 'RB'), ('step', 'VBZ'), ('one', 'RB'), ('workout', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('fun', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('beginner', 'PRP'), ('series', 'VBZ'), ('perfect', 'DT')],
#  [('great', 'JJ'), ('cardia', 'NN'), ('fun', 'NN')],
#  [('well', 'RB'),
#   ('do', 'VBN'),
#   ('break', 'NN'),
#   ('thing', 'NNS'),
#   ('clearly', 'RP'),
#   ('beginner', 'RB')],
#  [('bad', 'RB'), ('instructor', 'JJ'), ('funny', 'DT'), ('break', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('love', 'IN'), ('lot', 'PRP'), ('fun', 'PRP')],
#  [('great', 'JJ'), ('beginner', 'NN'), ('rumba', 'NN')],
#  [('great', 'JJ'),
#   ('easy', 'JJ'),
#   ('begin', 'VBG'),
#   ('level', 'NN'),
#   ('rumba', 'NN'),
#   ('someone', 'IN'),
#   ('want', 'NN'),
#   ('get', 'VBG')],
#  [('good', 'JJ'),
#   ('basic', 'JJ'),
#   ('dance', 'NN'),
#   ('step', 'NNS'),
#   ('without', 'IN'),
#   ('lot', 'DT'),
#   ('heavy', 'NN'),
#   ('carbon', 'IN')],
#  [('love', 'VB')],
#  [('love', 'VB')],
#  [('terrific', 'NN')],
#  [('love', 'VB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('long', 'RB'),
#   ('sleeved', 'JJ'),
#   ('version', 'NN'),
#   ('best', 'IN'),
#   ('lightweight', 'DT'),
#   ('polo', 'JJS'),
#   ('shirt', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('pleased', 'PRP')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'), ('lay', 'IN'), ('par', 'VBG'), ('5', 'RP')],
#  [('armour', 'IN'), ('favorite', 'NN'), ('clothing', 'VBZ'), ('line', 'PRP$')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('expensive', 'JJ'), ('quality', 'CC')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('easy', 'JJ'), ('gift', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('love', 'VB')],
#  [('perfect', 'NN')],
#  [('fantastic', 'JJ'), ('gift', 'NN'), ('true', 'IN'), ('fan', 'DT')],
#  [('perfect', 'NN'), ('blow', 'PRP'), ('away', 'VBD')],
#  [('typical', 'RB'),
#   ('shirt', 'DT'),
#   ('soft', 'JJ'),
#   ('cotton', 'NN'),
#   ('material', 'NN')],
#  [('great', 'JJ'), ('little', 'JJ'), ('holster', 'NN')],
#  [('perfect', 'JJ'), ('fit', 'NN')],
#  [('wonderful', 'JJ'), ('holster', 'NN')],
#  [('want', 'RB')],
#  [('work', 'NNS'), ('perfect', 'VBP'), ('naa', 'IN'), ('gun', 'DT')],
#  [('excellent', 'NN'), ('small', 'IN'), ('gun', 'JJ')],
#  [('nice', 'JJ'), ('product', 'NN')],
#  [('naa', 'RB'),
#   ('leather', 'RB'),
#   ('holster', 'NN'),
#   ('22', 'IN'),
#   ('mag', 'CD')],
#  [('nice', 'JJ')],
#  [('great', 'JJ'), ('little', 'JJ'), ('holster', 'NN')],
#  [('perfect', 'JJ'), ('fit', 'NN')],
#  [('wonderful', 'JJ'), ('holster', 'NN')],
#  [('want', 'RB')],
#  [('work', 'NNS'), ('perfect', 'VBP'), ('naa', 'IN'), ('gun', 'DT')],
#  [('excellent', 'NN'), ('small', 'IN'), ('gun', 'JJ')],
#  [('nice', 'JJ'), ('product', 'NN')],
#  [('naa', 'RB'),
#   ('leather', 'RB'),
#   ('holster', 'NN'),
#   ('22', 'IN'),
#   ('mag', 'CD')],
#  [('nice', 'JJ')],
#  [('solid', 'JJ'), ('holster', 'NN')],
#  [('best', 'JJS'),
#   ('naa', 'NN'),
#   ('mag', 'NN'),
#   ('iwc', 'NN'),
#   ('holster', 'NN'),
#   ('around', 'IN')],
#  [('one', 'CD'), ('star', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('fit', 'NN'), ('good', 'VBZ'), ('snug', 'JJ')],
#  [('might', 'MD'), ('great', 'VB')],
#  [('case', 'RB')],
#  [('ready', 'JJ')],
#  [('great', 'JJ'), ('travel', 'NN'), ('companion', 'NN')],
#  [('perfect', 'JJ'), ('size', 'NN'), ('draw', 'CC')],
#  [('good', 'JJ'), ('door', 'RP'), ('filter', 'JJ'), ('straw', 'NN')],
#  [('sound', 'NNS'), ('good', 'JJ'), ('capacity', 'CC'), ('limited', 'NN')],
#  [('rich', 'JJ'), ('people', 'NNS'), ('need', 'VBP'), ('hobby', 'NNS')],
#  [('long', 'RB')],
#  [('hard', 'TO'),
#   ('suck', 'VB'),
#   ('could', 'TO'),
#   ('use', 'VB'),
#   ('filter', 'RP')],
#  [('nice', 'JJ'), ('skate', 'NNS')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('fun', 'NN'), ('time', 'NNS')],
#  [('great', 'JJ')],
#  [('great', 'JJ'), ('adjustable', 'JJ'), ('skate', 'NNS')],
#  [('absolutely', 'NN'), ('love', 'RB'), ('skate', 'IN'), ('girl', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('latch', 'NNS'),
#   ('strip', 'VBP'),
#   ('easy', 'JJ'),
#   ('son', 'CC'),
#   ('want', 'PRP$'),
#   ('red', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'), ('fit', 'NN'), ('good', 'CC'), ('skate', 'JJ')],
#  [('adjustable', 'PRP'), ('skate', 'VBP')],
#  [('great', 'JJ'), ('quality', 'NN'), ('skate', 'NNS'), ('beginner', 'IN')],
#  [('happy', 'JJ'), ('purchase', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'), ('skate', 'NN')],
#  [('perfect', 'NN')],
#  [('red', 'JJ'),
#   ('color', 'NN'),
#   ('pic', 'IN'),
#   ('mislead', 'NN'),
#   ('hot', 'VBZ'),
#   ('pink', 'VBG'),
#   ('red', 'PRP')],
#  [('yes', 'NNS'), ('perfect', 'VBP'), ('gift', 'NN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('6', 'VBD'), ('month', 'PRP'), ('still', 'IN'), ('perfect', 'RB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('comfy', 'NN'), ('easy', 'CC'), ('adjust', 'JJ')],
#  [('perfect', 'NN'), ('skate', 'NNS')],
#  [('five', 'CD'), ('year', 'NN'), ('old', 'JJ'), ('love', 'VBZ')],
#  [('perfect', 'NN'), ('kid', 'IN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('quality', 'NN')],
#  [('fit', 'NNS'), ('size', 'NN'), ('11', 'CD'), ('boy', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [],
#  [('child', 'PRP$'),
#   ('love', 'NN'),
#   ('even', 'IN'),
#   ('though', 'PRP'),
#   ('look', 'RB'),
#   ('use', 'IN')],
#  [('rink', 'DT'),
#   ('7', 'NN'),
#   ('year', 'IN'),
#   ('old', 'PRP$'),
#   ('enjoy', 'CD')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('son', 'NN'), ('love', 'VBZ'), ('live', 'DT')],
#  [('great', 'JJ'), ('far', 'RB')],
#  [('ok', 'NN')],
#  [('kid', 'NNS'), ('love', 'VBP')],
#  [('roller', 'NN'), ('skate', 'NNS')],
#  [('say', 'VBZ'),
#   ('look', 'PRP'),
#   ('really', 'VBP'),
#   ('cool', 'RB'),
#   ('comfortable', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('skate', 'NNS')],
#  [('learner', 'NN'), ('skate', 'NN')],
#  [('great', 'JJ'),
#   ('skate', 'NNS'),
#   ('wish', 'VBP'),
#   ('size', 'DT'),
#   ('range', 'NN'),
#   ('different', 'NN')],
#  [('4', 'PRP$'), ('year', 'CD'), ('old', 'NN'), ('love', 'JJ')],
#  [('great', 'JJ'), ('kid', 'IN')],
#  [('happy', 'RB'), ('skate', 'JJ')],
#  [('boy', 'PRP$'), ('love', 'NN'), ('new', 'VBZ'), ('skate', 'PRP$')],
#  [('easy', 'JJ'), ('easy', 'IN'), ('adjust', 'JJ')],
#  [('satisfied', 'JJ'), ('customer', 'NN')],
#  [('little', 'JJ'), ('boy', 'NNS'), ('skate', 'VBP')],
#  [('ticket', 'RB')],
#  [('good', 'JJ'), ('price', 'IN')],
#  [('use', 'VBN'),
#   ('good', 'TO'),
#   ('solid', 'VB'),
#   ('wheel', 'JJ'),
#   ('safety', 'JJ'),
#   ('hazard', 'NNS')],
#  [('nice', 'JJ'), ('wheel', 'NN'), ('job', 'VBZ')],
#  [('great', 'JJ'), ('wheel', 'NNS'), ('price', 'IN')],
#  [('ok', 'PRP')],
#  [('like', 'RB'),
#   ('original', 'IN'),
#   ('classic', 'DT'),
#   ('plate', 'JJ'),
#   ('think', 'JJ'),
#   ('plate', 'NN'),
#   ('might', 'CC')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('aluminum', 'NN'),
#   ('rim', 'NN'),
#   ('5', 'IN'),
#   ('6', 'CD'),
#   ('speed', 'CC')],
#  [('true', 'JJ'), ('perfect', 'RB'), ('box', 'JJ')],
#  [('simple', 'NN'), ('install', 'TO'), ('solid', 'VB'), ('inexpensive', 'JJ')],
#  [('bomb', 'DT')],
#  [('best', 'DT'), ('outdoor', 'JJS'), ('climbing', 'IN'), ('gym', 'NN')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('perfect', 'NN')],
#  [('great', 'JJ'), ('belaying', 'NN'), ('device', 'NN')],
#  [('easy', 'JJ'), ('use', 'TO')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('solid', 'JJ'),
#   ('belay', 'NN'),
#   ('device', 'NN'),
#   ('bit', 'DT'),
#   ('finicky', 'NN'),
#   ('first', 'JJ')],
#  [('item', 'DT'),
#   ('market', 'JJ'),
#   ('would', 'NNS'),
#   ('good', 'IN'),
#   ('choice', 'DT'),
#   ('purpose', 'NN')],
#  [('one', 'CD'),
#   ('safe', 'IN'),
#   ('belay', 'DT'),
#   ('device', 'JJS'),
#   ('use', 'NN'),
#   ('properly', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('old', 'NN'),
#   ('green', 'VBP'),
#   ('line', 'DT'),
#   ('guy', 'JJ'),
#   ('use', 'JJ'),
#   ('new', 'NN'),
#   ('stuff', 'NN'),
#   ('take', 'RB'),
#   ('grain', 'VBN'),
#   ('salt', 'TO')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('belay', 'NN'),
#   ('device', 'NN'),
#   ('end', 'VBD'),
#   ('buy', 'RP'),
#   ('second', 'VBG'),
#   ('one', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'CC'),
#   ('control', 'RB'),
#   ('also', 'PRP'),
#   ('comfort', 'VBZ'),
#   ('know', 'JJR')],
#  [('thick', 'RB'), ('rope', 'IN')],
#  [('great', 'JJ'), ('product', 'NN'), ('fast', 'CC'), ('shipping', 'JJ')],
#  [('like', 'NN'), ('lot', 'VBD')],
#  [('work', 'NNS'), ('well', 'RB')],
#  [('exactly', 'RB'), ('described', 'IN')],
#  [('mu', 'NN'),
#   ('favorite', 'NN'),
#   ('descend', 'VBD'),
#   ('like', 'NN'),
#   ('simple', 'IN'),
#   ('atc', 'DT')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('5', 'CD'),
#   ('thing', 'NNS'),
#   ('consider', 'TO'),
#   ('buy', 'VB'),
#   ('belay', 'IN'),
#   ('device', 'VBG')],
#  [('grigori', 'DT'),
#   ('2', 'NN'),
#   ('great', 'CD'),
#   ('belay', 'VBZ'),
#   ('device', 'DT'),
#   ('climber', 'JJ'),
#   ('climb', 'NN'),
#   ('long', 'NN'),
#   ('climb', 'IN')],
#  [('great', 'JJ')],
#  [('ultimate', 'DT'), ('belay', 'JJ'), ('device', 'NN')],
#  [('love', 'VB'), ('old', 'PRP'), ('model', 'IN')],
#  [('love', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('device', 'NN'),
#   ('belaying', 'NN'),
#   ('become', 'VBD'),
#   ('lot', 'DT'),
#   ('easy', 'NN')],
#  [('petal', 'DT'),
#   ('grigori', 'JJ'),
#   ('gold', 'NN'),
#   ('standard', 'VBZ'),
#   ('belay', 'DT'),
#   ('device', 'JJ')],
#  [('work', 'NNS'), ('perfectly', 'RB')],
#  [('perfect', 'NN')],
#  [('great', 'JJ'), ('device', 'NN')],
#  [('amazing', 'JJ'), ('improvement', 'NN')],
#  [('light', 'JJR'), ('original', 'IN'), ('useful', 'DT')],
#  [('light', 'JJR'), ('original', 'IN'), ('useful', 'DT')],
#  [('grigori', 'NN'), ('rock', 'NNS')],
#  [('light', 'JJR'), ('original', 'IN'), ('useful', 'DT')],
#  [('light', 'JJR'), ('original', 'IN'), ('useful', 'DT')],
#  [('light', 'JJR'), ('original', 'IN'), ('useful', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('nice', 'RB'), ('although', 'JJ'), ('new', 'IN'), ('version', 'DT')],
#  [('love', 'VB'), ('grigori', 'DT'), ('2', 'NN')],
#  [('large', 'JJ'), ('finer', 'NN')],
#  [('perfect', 'NN'), ('use', 'IN')],
#  [('convenient', 'NN')],
#  [('handy', 'JJ'), ('large', 'JJ'), ('utility', 'NN'), ('karabiner', 'NN')],
#  [('5', 'CD'), ('star', 'NN')],
#  [('good', 'JJ'), ('product', 'NN')],
#  [('surprise', 'DT')],
#  [('handy', 'NN'), ('car', 'IN')],
#  [('foam', 'NN'), ('tear', 'VBD'), ('easily', 'RB')],
#  [('work', 'NNS'), ('light', 'IN'), ('load', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('impress', 'JJ'), ('quality', 'NNS')],
#  [('life', 'NN'), ('make', 'VBD'), ('easy', 'JJR')],
#  [('good', 'JJ'), ('buy', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('whatever', 'WDT')],
#  [('disappoint', 'VBN'), ('purchase', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('work', 'NNS'),
#   ('great', 'JJ'),
#   ('haul', 'VB'),
#   ('one', 'PRP'),
#   ('trip', 'DT')],
#  [('excellent', 'JJ'), ('quality', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('work', 'NNS'), ('well', 'RB')],
#  [('perfect', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('well', 'RB'), ('make', 'VBN'), ('useful', 'CC')],
#  [('break', 'VBD'), ('first', 'DT'), ('time', 'JJ'), ('use', 'NN')],
#  [('finer', 'NN')],
#  [('hand', 'PRP$'), ('thank', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('love', 'VB'), ('big', 'DT'), ('guy', 'JJ')],
#  [('want', 'PRP'), ('big', 'VBP'), ('get', 'JJ')],
#  [('perfect', 'NN'), ('solo', 'IN'), ('backpacking', 'NN')],
#  [('nice', 'RB'), ('kit', 'JJ')],
#  [('first', 'DT'), ('aid', 'JJ'), ('kit', 'NN'), ('name', 'NN')],
#  [('convenient', 'RB')],
#  [('good', 'JJ'), ('standard', 'NN'), ('kit', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'PRP'), ('well', 'VBP'), ('make', 'JJ')],
#  [('quick', 'IN'), ('grab', 'DT'), ('go', 'JJ'), ('fine', 'NN')],
#  [('great', 'JJ'),
#   ('start', 'VBG'),
#   ('point', 'NN'),
#   ('lightweight', 'IN'),
#   ('always', 'DT'),
#   ('day', 'JJ'),
#   ('trip', 'RB'),
#   ('kit', 'IN')],
#  [('good', 'JJ'), ('around', 'DT'), ('kit', 'IN')],
#  [('dream', 'NN'), ('weight', 'NN')],
#  [('ultralight', 'NN'), ('great', 'VBZ'), ('value', 'DT')],
#  [('decent', 'NN'),
#   ('first', 'RB'),
#   ('aid', 'JJ'),
#   ('kit', 'NN'),
#   ('minor', 'IN'),
#   ('cut', 'JJ'),
#   ('scrape', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('perfect', 'NN'),
#   ('med', 'VBD'),
#   ('kit', 'NN'),
#   ('keep', 'TO'),
#   ('single', 'VB'),
#   ('track', 'IN'),
#   ('back', 'PRP$'),
#   ('pack', 'JJ')],
#  [('great', 'DT'),
#   ('little', 'VBZ'),
#   ('kit', 'DT'),
#   ('emergency', 'JJ'),
#   ('bag', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('adventure', 'NN'), ('medical', 'JJ'), ('kit', 'NN'), ('5', 'CD')],
#  [('adventure', 'NN'), ('medical', 'JJ'), ('kit', 'NN')],
#  [('bike', 'PRP$'), ('first', 'IN'), ('aid', 'NN'), ('kit', 'RB')],
#  [('great', 'JJ'), ('day', 'IN'), ('hike', 'DT'), ('bag', 'NN')],
#  [('good', 'DT'),
#   ('1', 'RB'),
#   ('2', 'JJ'),
#   ('day', 'CD'),
#   ('hike', 'CD'),
#   ('first', 'NN'),
#   ('aid', 'VB'),
#   ('kit', 'JJ')],
#  [('compact', 'JJ'),
#   ('easy', 'JJ'),
#   ('carry', 'TO'),
#   ('surprisingly', 'VB'),
#   ('complete', 'RB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('little', 'JJ'),
#   ('kit', 'NN'),
#   ('truly', 'RB'),
#   ('waterproof', 'JJ')],
#  [('outstanding', 'JJ'),
#   ('thing', 'NN'),
#   ('get', 'TO'),
#   ('especially', 'VB'),
#   ('person', 'RB')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('always', 'NN'),
#   ('worry', 'RB'),
#   ('buy', 'VBP'),
#   ('something', 'IN'),
#   ('like', 'VBG'),
#   ('line', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('go', 'VB'),
#   ('ahead', 'RB'),
#   ('recommend', 'JJ'),
#   ('useful', 'VBP'),
#   ('many', 'JJ'),
#   ('calibre', 'IN'),
#   ('variety', 'JJ'),
#   ('free', 'NN'),
#   ('hand', 'NNS')],
#  [('great', 'JJ'), ('buy', 'NN'), ('money', 'IN'), ('imho', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('must', 'DT'), ('pepper', 'MD')],
#  [('tactical', 'JJ'), ('vest', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'), ('vest', 'NN')],
#  [('would', 'MD'), ('buy', 'VB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('go', 'DT'), ('great', 'VBZ'), ('take', 'VBG'), ('range', 'TO')],
#  [('four', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('fit', 'JJ'),
#   ('even', 'RB'),
#   ('portly', 'IN'),
#   ('fellow', 'DT'),
#   ('like', 'RB')],
#  [('nice', 'RB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('comfortable', 'JJ'), ('versatile', 'NN'), ('vest', 'NN')],
#  [('must', 'DT'), ('buy', 'MD')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('item', 'NN'),
#   ('well', 'RBR'),
#   ('price', 'NN'),
#   ('place', 'IN')],
#  [('great', 'JJ'), ('product', 'NN'), ('money', 'IN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'),
#   ('tact', 'JJ'),
#   ('vest', 'NN'),
#   ('great', 'IN'),
#   ('price', 'DT')],
#  [('unbeatable', 'JJ'), ('vest', 'NN')],
#  [('best', 'JJS'),
#   ('bang', 'NN'),
#   ('buck', 'IN'),
#   ('tug', 'PRP$'),
#   ('get', 'NN'),
#   ('right', 'NN')],
#  [('serious', 'RB'), ('piece', 'DT'), ('equipment', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('worth', 'IN'), ('buy', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'), ('quality', 'NN'), ('complaint', 'PRP$')],
#  [('plenty', 'NN'), ('bang', 'IN'), ('buck', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('excellent', 'NN'),
#   ('rugged', 'VBD'),
#   ('well', 'RB'),
#   ('make', 'VBN'),
#   ('recommend', 'NN')],
#  [('look', 'VBZ'),
#   ('like', 'RB'),
#   ('picture', 'JJ'),
#   ('totally', 'NN'),
#   ('adjustable', 'RB'),
#   ('sizing', 'JJ'),
#   ('strong', 'NN')],
#  [('long', 'RB'), ('short', 'RB'), ('people', 'IN')],
#  [('multi', 'DT'),
#   ('functional', 'JJ'),
#   ('rugged', 'NN'),
#   ('well', 'VBN'),
#   ('conceive', 'RB'),
#   ('vest', 'VBN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('best', 'JJS'), ('bang', 'NN'), ('buck', 'IN')],
#  [('recommend', 'RB'), ('pointed', 'VBN'), ('tool', 'IN')],
#  [('great', 'JJ'), ('price', 'IN')],
#  [('need', 'PRP')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('decent', 'IN'),
#   ('material', 'JJ'),
#   ('put', 'NN'),
#   ('together', 'VBD'),
#   ('well', 'RB'),
#   ('good', 'RB'),
#   ('price', 'RB')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('really', 'MD'),
#   ('go', 'VB'),
#   ('wrong', 'RB'),
#   ('price', 'VB'),
#   ('vest', 'JJ')],
#  [('zombie', 'NN'), ('apocalypse', 'VBZ'), ('problem', 'DT'), ('baby', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('pocket', 'DT'), ('everything', 'NN')],
#  [('nice', 'RB'), ('tactical', 'CC')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('look', 'NNS'),
#   ('nice', 'JJ'),
#   ('feel', 'NNS'),
#   ('nice', 'JJ'),
#   ('sometimes', 'CC'),
#   ('forget', 'RB'),
#   ('replica', 'JJ')],
#  [('nice', 'JJ'), ('durable', 'JJ'), ('vest', 'NN')],
#  [('prob', 'NN'),
#   ('everyday', 'RB'),
#   ('use', 'IN'),
#   ('like', 'JJ'),
#   ('combat', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'RB'), ('product', 'JJ'), ('price', 'NN')],
#  [('great', 'JJ'), ('vest', 'NN')],
#  [('nice', 'JJ'),
#   ('adjustable', 'JJ'),
#   ('fit', 'JJ'),
#   ('many', 'JJ'),
#   ('pocket', 'NNS'),
#   ('gizmo', 'IN'),
#   ('gadget', 'NN')],
#  [('awesome', 'VBZ'), ('vest', 'VBZ'), ('happy', 'DT'), ('price', 'JJ')],
#  [('nice', 'JJ'),
#   ('product', 'NN'),
#   ('build', 'VBN'),
#   ('well', 'RB'),
#   ('last', 'CC')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('nice', 'RB'),
#   ('make', 'JJ'),
#   ('fit', 'IN'),
#   ('adjustment', 'VBG'),
#   ('impress', 'JJ')],
#  [('nice', 'PRP'), ('vest', 'VBZ'), ('far', 'DT'), ('like', 'JJ')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('fit', 'NNS'),
#   ('great', 'JJ'),
#   ('wish', 'JJ'),
#   ('loop', 'PRP'),
#   ('back', 'VBD')],
#  [('nice', 'PRP'), ('vest', 'VBZ'), ('know', 'DT'), ('make', 'JJ')],
#  [('exceptional', 'JJ'), ('quality', 'NN')],
#  [('exceptional', 'JJ'), ('tactical', 'JJ'), ('vest', 'NN')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('great', 'JJ'), ('tactical', 'JJ'), ('vest', 'NN')],
#  [('dad', 'PRP$'), ('uncle', 'NN'), ('love', 'CC')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('good', 'JJ'), ('investment', 'NN')],
#  [('load', 'NNS'),
#   ('pocket', 'IN'),
#   ('stuff', 'NNS'),
#   ('big', 'IN'),
#   ('guy', 'DT'),
#   ('230lbs', 'PRP$'),
#   ('fit', 'NN'),
#   ('fine', 'CC'),
#   ('love', 'JJ'),
#   ('remove', 'VBP'),
#   ('firearm', 'DT')],
#  [('five', 'CD'), ('star', 'NNS')],
#  [('nice', 'JJ')],
#  [('need', 'VBZ'),
#   ('good', 'DT'),
#   ('belt', 'JJR'),
#   ('support', 'NN'),
#   ('fully', 'TO'),
#   ('load', 'VB'),
#   ('vest', 'DT')],
#  [('love', 'VB')],
#  [('great', 'JJ'), ('vest', 'JJS'), ('highly', 'RB'), ('recommend', 'VB')],
#  ...]

# %%
i = 1
print(summary[i])
print(lem_summary_text[i])
# Out:
# Much better than plastic caps.
# [('much', 'RB'), ('good', 'JJR'), ('plastic', 'IN'), ('cap', 'NN')]

# %%
from sklearn.base import TransformerMixin, BaseEstimator

# expects corpus of tuples as input, (word, part-of-speach)
# nltk.pos_tagger has the following pos_tag convention
# N* - noun
# J* - adjective
# V* - verb
# R* - adverb
# use nltk.help.upenn_tagset('CD') to reverse lookup tags, 
# where CD is whatever your tag is
class posDoc(TransformerMixin, BaseEstimator):
    def __init__(self, pos_tag="N"):
        self.pos_tag = pos_tag
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        X_ = []
        for doc in X:
            this_doc = [word[0] for word in doc 
                        if word[1][:len(self.pos_tag)] == self.pos_tag]
            this_doc.append('null') # prior value to avoid null set return
            X_.append(this_doc)
        return X_
    
# see here regarding this function:
# https://stackoverflow.com/questions/41881086/valueerror-with-scikit-learn-plsregression-when-used-in-pipeline
class PLSRegressionWrapper(PLSRegression):
    def transform(self, X):
        return super().transform(X)

    def fit_transform(self, X, Y):
        return self.fit(X,Y).transform(X)

# %%
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.decomposition import PCA

from gensim.models import Word2Vec, KeyedVectors
    
class getLatentWord(TransformerMixin, BaseEstimator):
    
    def __init__(self):
        self.model = KeyedVectors.load_word2vec_format('../../../GoogleNews-vectors-negative300.bin', binary=True)
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        cumWord = []
        for review in X:
            review_word_vec = [self.model[word] for word in review 
                                   if self.model.vocab.__contains__(word)]
            review_word_vec.append(self.model['null']) # works as prior so that we can score empty reviews
            cumWord.append(np.sum(review_word_vec, axis=0))
        return cumWord
    
            
# assumes words are already in latent representation
class getLatentTopics(TransformerMixin, BaseEstimator):
    
    # takes words as input
    def fit(self, X, y=None):
        
        # train a document-topic model        
        self.pca = PCA(n_components = 100)
        self.pca.fit(X)
        
        return self
    
    def transform(self, X, y=None):
        
        return self.pca.transform(X)
    
class docTopTransformer(BaseEstimator):

# %%
# fit some example models to see what's being misclassified or correctly classified

from sklearn.model_selection import cross_val_predict, GroupKFold
from sklearn.svm import LinearSVC, SVC
from sklearn import tree
from sklearn.ensemble import BaggingClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.cross_decomposition import PLSRegression
    
from sklearn.pipeline import Pipeline
from copy import deepcopy

idx = np.random.permutation([x for x in range(0, len(lem_summary_text))])
sample_idx = idx[0:np.power(2,14)]

train_lbls = awesome[sample_idx]
this_prod_id = [prod_id[i] for i in sample_idx]
lem_train_text = deepcopy([lem_summary_text[i] for i in sample_idx])

gkf = GroupKFold(n_splits=5)
cv = gkf.split(lem_train_text, train_lbls, groups=this_prod_id)
n_dim = 4

nounSpace = Pipeline([('getNoun', posDoc(pos_tag="N")), ('doc2Top',docTopTransformer2(d=75)), 
                      ('dRedux', PLSRegressionWrapper(n_components=n_dim))])
verbSpace = Pipeline([('getNoun', posDoc(pos_tag="V")), ('doc2Top',docTopTransformer2(d=75)), 
                      ('dRedux', PLSRegressionWrapper(n_components=n_dim))])
advSpace = Pipeline([('getNoun', posDoc(pos_tag="R")), ('doc2Top',docTopTransformer2(d=75)), 
                      ('dRedux', PLSRegressionWrapper(n_components=n_dim))])
adjSpace = Pipeline([('getNoun', posDoc(pos_tag="J")), ('doc2Top',docTopTransformer2(d=75)), 
                      ('dRedux', PLSRegressionWrapper(n_components=n_dim))])
numSpace = Pipeline([('getNoun', posDoc(pos_tag="CD")), ('doc2Top',docTopTransformer2(d=10)), 
                      ('dRedux', PLSRegressionWrapper(n_components=n_dim))])
featureExtract = FeatureUnion([('nouns', nounSpace), ('verbs', verbSpace), ('adv', advSpace), 
                               ('adj', adjSpace), ('numbers', numSpace)])

clf = SVC(kernel='poly', degree=2)

estimators = [('getFeatures', featureExtract), ('classify', clf)]
semClf = Pipeline(estimators)

t0 = time.time()
predict = cross_val_predict(semClf, lem_train_text, train_lbls, cv=cv)
t1 = time.time()

print(t1-t0)

print(1 - np.sum(predict != train_lbls)/len(train_lbls))
# Out:
# 47.938727140426636
# 0.75799560546875

# %%
from sklearn.metrics import classification_report

report = classification_report(train_lbls, predict)
print('Summary Text Prediction')
print(report)
# Out:
# Summary Text Prediction
#               precision    recall  f1-score   support
#
#        False       0.84      0.34      0.48      5450
#         True       0.75      0.97      0.84     10934
#
#     accuracy                           0.76     16384
#    macro avg       0.79      0.65      0.66     16384
# weighted avg       0.78      0.76      0.72     16384

# %%
test_idx = [i for i in range(0,18000) if i not in sample_idx]
#lem_train_text = deepcopy([lem_summary_text[i] for i in sample_idx])
#doc2wordEmb = getLatentWord()
semClf = semClf.fit(lem_train_text, train_lbls)

test_lbls = awesome[test_idx]
test_text = deepcopy([lem_summary_text[i] for i in test_idx])

# %%
predict2 = semClf.predict(test_text)
print(1 - np.sum(predict2 != test_lbls)/len(test_lbls))
